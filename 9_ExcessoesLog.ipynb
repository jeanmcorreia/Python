# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanmcorreia/Python/blob/main/9_ExcessoesLog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Inicio")
lista = [1, 2, 3]
print(lista[10])
print("fim")

# %%
print("Inicio")
lista = [1, 2, 3]
try:
  print(lista[1])
except:
  print("Falha ao acessar, linha não encontrada")
print("fim")
# Out:
# Inicio
# 2
# fim

# %%
print("Inicio")
lista = [1, 2, 3]
try:
  print(lista[10])
except Exception as error:
  print(f"Falha ao acessar, linha não encontrada, messagem: {error}")
print("fim")
# Out:
# Inicio
# Falha ao acessar, linha não encontrada, messagem: list index out of range
# fim

# %%
try:
  num = int("b")
except Exception as error:
  print(f"Falha no cast: {error}")
# Out:
# Falha no cast: invalid literal for int() with base 10: 'b'

# %%
print("Inicio")
lista = [1, 2, 3]
try:
  print(lista[0])
except:
  print("Falha ao acessar, linha não encontrada")
finally:
  del lista
  print('Executa sempre que o try-except encerra, mesmo que não ocorra erro')
print("fim")
# Out:
# Inicio
# 1
# Executa sempre que o try-except encerra, mesmo que não ocorra erro
# fim

# %%
print("Inicio")
lista = [1, 2, 3]
try:
  print(lista[10])
except:
  print("Falha ao acessar, linha não encontrada")
else:
  print('Não houve erro')
print("fim")
# Out:
# Inicio
# Falha ao acessar, linha não encontrada
# fim

# %%
print("Inicio")
lista = [1, 2, 3]
try:
  print(lista[10])
except:
  print("Falha ao acessar, linha não encontrada")
else:
  print("Não houve erro")
finally:
  print("Executa sempre")
print("fim")
# Out:
# Inicio
# Falha ao acessar, linha não encontrada
# Executa sempre
# fim

# %%
print("ínicio")
lista = [1,2,3]

try:
  print(lista[2])
except IndexError as error1:
  print(f"Erro de acesso ao índice {error1}")
except:
  print("Ocorreu outro erro")
else:
  print("Executa se não houver erro")

print("Fim")
# Out:
# ínicio
# 3
# Executa se não houver erro
# Fim

# %%
print("ínicio")
lista = [1,2,3]
numero = 0
try:
  divisao = 10 / numero
  print(lista[12])
except IndexError as error1:
  print(f"Erro de acesso ao índice {error1}")
except ZeroDivisionError as erro2:
  print(f"Erro de divisão por zero: {erro2}")
except Exception as erro3:
  print(f"Ocorreu outro erro: {erro3}")
else:
  print("Executa se não houver erro")

print("Fim")
# Out:
# ínicio
# Erro de divisão por zero: division by zero
# Fim
